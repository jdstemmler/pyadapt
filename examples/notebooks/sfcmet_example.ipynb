# %%
import pyadapt
import os
# %matplotlib inline

# %%
dat_dir = './data'
fname = 'grwmetM1.b1.20100531.000000.cdf'

fqfn = os.path.join(dat_dir, fname)
print(fqfn)
# Out:
# ./data/grwmetM1.b1.20100531.000000.cdf

# %%
sfc = pyadapt.read(fqfn)

# %%
dir(sfc)
# Out:
# ['__doc__',
#  '__init__',
#  '__module__',
#  'comment',
#  'data',
#  'dimensions',
#  'file_datetime',
#  'keys',
#  'kind',
#  'long_name',
#  'missing_value',
#  'plot',
#  'site_id',
#  'units']

# %%
sfc.plot()
