# %%
import pyadapt
import matplotlib
# %matplotlib inline
#reload(pyadapt)

# %%
dat_dir = '/home/jstemm/Documents/research/data/soundings/'
dat_file = 'grwsondewnpnM1.b1.20100531.112900.cdf'

filename = dat_dir + dat_file

# %%
S = pyadapt.read(filename)
#dir(S)

# %%
S.plot(ptop=100, plot_output=True, autoname=True)
