# %%
import pyadapt
import matplotlib
import os
# %matplotlib inline
#reload(pyadapt)

# %%
dat_file = os.path.abspath('../data/grwsondewnpnM1.b1.20100531.112900.cdf')
S = pyadapt.read(filename)
S.plot()
