# %%
import pyadapt
#reload(pyadapt)

# %%
dat_dir = '/home/jstemm/Documents/research/data/soundings/'
dat_file = 'grwsondewnpnM1.b1.20100531.000100.cdf'

filename = dat_dir + dat_file

# %%
S = pyadapt.read(filename)
dir(S)
# Out:
# ['__doc__',
#  '__init__',
#  '__module__',
#  'data',
#  'dimensions',
#  'keys',
#  'long_name',
#  'missing_value',
#  'plot',
#  'units']

# %%
S.plot(altmax=15000)
