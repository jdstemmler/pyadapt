# %%
import pyadapt
# %matplotlib inline

# %%
dat_dir = '/home/jstemm/Documents/research/data/'
stream = 'sfcmet/'
fname = 'grwmetM1.b1.20090531.000000.cdf'

fqfn = dat_dir + stream + fname

# %%
sfc = pyadapt.read(fqfn)

# %%
dir(sfc)
# Out:
# ['__doc__',
#  '__init__',
#  '__module__',
#  'comment',
#  'data',
#  'dimensions',
#  'file_datetime',
#  'filename',
#  'keys',
#  'kind',
#  'long_name',
#  'missing_value',
#  'plot',
#  'sample_int',
#  'site_id',
#  'units']

# %%
sfc.plot()
